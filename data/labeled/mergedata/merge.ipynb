# %%
filename = [
    "./vihsd_groupdata_merge/final_merge_dataset_by_group_cleaned.csv",
    "./vihsd_groupdata_merge/train_cleaned.csv"
]

with open("final_merge.csv", "w", encoding="utf-8") as fout:
    for f in filename:
        with open(f, "r", encoding="utf-8") as fin:
            for line in fin:
                fout.write(line)
